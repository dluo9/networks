# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
G = nx.erdos_renyi_graph(10, 0.5)
nx.draw(G)
plt.show()

# %%
def sample_ER_graphs(num_graphs, n, p=0.5):
    degrees, num_edges = [], []
    for _ in range(num_graphs):
        G = nx.erdos_renyi_graph(n, p)
        means = (np.mean(nx.degree(G)), nx.number_of_edges(G))
        degrees.append(means[0])
        num_edges.append(means[1])
    
    fig, axes = plt.subplots(1,2, figsize=(16,8))
    sns.kdeplot(ax=axes[0], x=degrees, fill=True)
    axes[0].set(xlabel="Mean Degree in Sample")
    sns.kdeplot(ax=axes[1], x=num_edges, fill=True)
    axes[1].set(xlabel="Mean Number of Edges in Sample")
    plt.show()
    
    return(degrees, num_edges)

# %%
degrees, num_edges = sample_ER_graphs(1000, 100)

# %%
display(np.mean(degrees), np.mean(num_edges))
# Out:
# 49.50103
# 2475.103

# %%
degrees, num_edges = sample_ER_graphs(100, 100)

# %%
display(np.mean(degrees), np.mean(num_edges))
# Out:
# 49.51079999999999
# 2476.08

# %%
degrees, num_edges = sample_ER_graphs(100, 1000)

# %%
display(np.mean(degrees), np.mean(num_edges))
# Out:
# 499.44497999999993
# 249694.98

# %%
degrees, num_edges = sample_ER_graphs(10000, 100)

# %%
display(np.mean(degrees), np.mean(num_edges))
# Out:
# 49.500533
# 2475.0533
